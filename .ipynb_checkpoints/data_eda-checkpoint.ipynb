# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df= pd.read_csv("cleaned_data.csv")
final_dataset= pd.read_csv("cleaned_numerical_data.csv")
df.head()
# Out:
#                      model_name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine  max_power  seats  \
# 0  Individual       Manual   First Owner    23.40  1248.0      74.00    5.0
# 1  Individual       Manual  Second Owner    21.14  1498.0     103.52    5.0
# 2  Individual       Manual   Third Owner    17.70  1497.0      78.00    5.0
# 3  Individual       Manual   First Owner    23.00  1396.0      90.00    5.0
# 4  Individual       Manual   First Owner    16.10  1298.0      88.20    5.0
#
#   company_name  no_of_years
# 0       Maruti            8
# 1        Skoda            8
# 2        Honda           16
# 3      Hyundai           12
# 4       Maruti           15

# %%
final_dataset.head()
# Out:
#    selling_price  km_driven  mileage  engine  max_power  seats  no_of_years  \
# 0         450000     145500    23.40  1248.0      74.00    5.0            8
# 1         370000     120000    21.14  1498.0     103.52    5.0            8
# 2         158000     140000    17.70  1497.0      78.00    5.0           16
# 3         225000     127000    23.00  1396.0      90.00    5.0           12
# 4         130000     120000    16.10  1298.0      88.20    5.0           15
#
#    fuel_Diesel  fuel_LPG  fuel_Petrol  seller_type_Individual  \
# 0            1         0            0                       1
# 1            1         0            0                       1
# 2            0         0            1                       1
# 3            1         0            0                       1
# 4            0         0            1                       1
#
#    seller_type_Trustmark Dealer  transmission_Manual  \
# 0                             0                    1
# 1                             0                    1
# 2                             0                    1
# 3                             0                    1
# 4                             0                    1
#
#    owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                           0                   0                     0
# 1                           0                   1                     0
# 2                           0                   0                     0
# 3                           0                   0                     0
# 4                           0                   0                     0
#
#    owner_Third Owner
# 0                  0
# 1                  0
# 2                  1
# 3                  0
# 4                  0

# %%
corr_matrix=final_dataset.corr()
corr_matrix
# Out:
#                               selling_price  km_driven   mileage    engine  \
# selling_price                      1.000000  -0.225534 -0.045405  0.445985
# km_driven                         -0.225534   1.000000 -0.175519  0.155493
# mileage                           -0.045405  -0.175519  1.000000 -0.139442
# engine                             0.445985   0.155493 -0.139442  1.000000
# max_power                          0.720341  -0.060763 -0.027941  0.752893
# seats                              0.088110   0.119630  0.164163  0.696653
# no_of_years                       -0.414092   0.418006 -0.406930 -0.129553
# fuel_Diesel                        0.206521   0.266368  0.062501  0.462455
# fuel_LPG                          -0.037222   0.023458 -0.024008 -0.058478
# fuel_Petrol                       -0.195975  -0.269802 -0.069281 -0.444905
# seller_type_Individual            -0.386244   0.204736 -0.013579 -0.134108
# seller_type_Trustmark Dealer       0.035084  -0.084282 -0.010376  0.047378
# transmission_Manual               -0.588845   0.201229  0.111906 -0.273145
# owner_Fourth & Above Owner        -0.075669   0.094939 -0.084275 -0.026417
# owner_Second Owner                -0.179881   0.209532 -0.111614 -0.004712
# owner_Test Drive Car               0.115880  -0.024214 -0.009670  0.014382
# owner_Third Owner                 -0.118956   0.145634 -0.129012 -0.042715
#
#                               max_power     seats  no_of_years  fuel_Diesel  \
# selling_price                  0.720341  0.088110    -0.414092     0.206521
# km_driven                     -0.060763  0.119630     0.418006     0.266368
# mileage                       -0.027941  0.164163    -0.406930     0.062501
# engine                         0.752893  0.696653    -0.129553     0.462455
# max_power                      1.000000  0.393829    -0.300136     0.286877
# seats                          0.393829  1.000000    -0.173232     0.272885
# no_of_years                   -0.300136 -0.173232     1.000000    -0.051762
# fuel_Diesel                    0.286877  0.272885    -0.051762     1.000000
# fuel_LPG                      -0.061652 -0.035206     0.070712    -0.074494
# fuel_Petrol                   -0.266738 -0.262090     0.044633    -0.976687
# seller_type_Individual        -0.275949  0.034134     0.246161    -0.000239
# seller_type_Trustmark Dealer   0.035685 -0.000900    -0.102238    -0.137961
# transmission_Manual           -0.513393  0.022955     0.244707     0.025519
# owner_Fourth & Above Owner    -0.051747 -0.027535     0.207020    -0.010638
# owner_Second Owner            -0.098159 -0.011549     0.311225     0.046762
# owner_Test Drive Car           0.047418 -0.005170    -0.031877    -0.017008
# owner_Third Owner             -0.082806 -0.057546     0.280220    -0.014272
#
#                               fuel_LPG  fuel_Petrol  seller_type_Individual  \
# selling_price                -0.037222    -0.195975               -0.386244
# km_driven                     0.023458    -0.269802                0.204736
# mileage                      -0.024008    -0.069281               -0.013579
# engine                       -0.058478    -0.444905               -0.134108
# max_power                    -0.061652    -0.266738               -0.275949
# seats                        -0.035206    -0.262090                0.034134
# no_of_years                   0.070712     0.044633                0.246161
# fuel_Diesel                  -0.074494    -0.976687               -0.000239
# fuel_LPG                      1.000000    -0.061584                0.021092
# fuel_Petrol                  -0.061584     1.000000               -0.008983
# seller_type_Individual        0.021092    -0.008983                1.000000
# seller_type_Trustmark Dealer -0.011852     0.142335               -0.385425
# transmission_Manual           0.026397    -0.034631                0.375234
# owner_Fourth & Above Owner    0.014785     0.007300                0.066360
# owner_Second Owner            0.017122    -0.051046                0.165983
# owner_Test Drive Car         -0.001700     0.017630               -0.055297
# owner_Third Owner             0.017199     0.012820                0.116236
#
#                               seller_type_Trustmark Dealer  \
# selling_price                                     0.035084
# km_driven                                        -0.084282
# mileage                                          -0.010376
# engine                                            0.047378
# max_power                                         0.035685
# seats                                            -0.000900
# no_of_years                                      -0.102238
# fuel_Diesel                                      -0.137961
# fuel_LPG                                         -0.011852
# fuel_Petrol                                       0.142335
# seller_type_Individual                           -0.385425
# seller_type_Trustmark Dealer                      1.000000
# transmission_Manual                              -0.149677
# owner_Fourth & Above Owner                       -0.025577
# owner_Second Owner                               -0.047034
# owner_Test Drive Car                             -0.004290
# owner_Third Owner                                -0.046814
#
#                               transmission_Manual  owner_Fourth & Above Owner  \
# selling_price                           -0.588845                   -0.075669
# km_driven                                0.201229                    0.094939
# mileage                                  0.111906                   -0.084275
# engine                                  -0.273145                   -0.026417
# max_power                               -0.513393                   -0.051747
# seats                                    0.022955                   -0.027535
# no_of_years                              0.244707                    0.207020
# fuel_Diesel                              0.025519                   -0.010638
# fuel_LPG                                 0.026397                    0.014785
# fuel_Petrol                             -0.034631                    0.007300
# seller_type_Individual                   0.375234                    0.066360
# seller_type_Trustmark Dealer            -0.149677                   -0.025577
# transmission_Manual                      1.000000                    0.041761
# owner_Fourth & Above Owner               0.041761                    1.000000
# owner_Second Owner                       0.119681                   -0.087438
# owner_Test Drive Car                    -0.049621                   -0.003670
# owner_Third Owner                        0.072274                   -0.040040
#
#                               owner_Second Owner  owner_Test Drive Car  \
# selling_price                          -0.179881              0.115880
# km_driven                               0.209532             -0.024214
# mileage                                -0.111614             -0.009670
# engine                                 -0.004712              0.014382
# max_power                              -0.098159              0.047418
# seats                                  -0.011549             -0.005170
# no_of_years                             0.311225             -0.031877
# fuel_Diesel                             0.046762             -0.017008
# fuel_LPG                                0.017122             -0.001700
# fuel_Petrol                            -0.051046              0.017630
# seller_type_Individual                  0.165983             -0.055297
# seller_type_Trustmark Dealer           -0.047034             -0.004290
# transmission_Manual                     0.119681             -0.049621
# owner_Fourth & Above Owner             -0.087438             -0.003670
# owner_Second Owner                      1.000000             -0.014667
# owner_Test Drive Car                   -0.014667              1.000000
# owner_Third Owner                      -0.160041             -0.006716
#
#                               owner_Third Owner
# selling_price                         -0.118956
# km_driven                              0.145634
# mileage                               -0.129012
# engine                                -0.042715
# max_power                             -0.082806
# seats                                 -0.057546
# no_of_years                            0.280220
# fuel_Diesel                           -0.014272
# fuel_LPG                               0.017199
# fuel_Petrol                            0.012820
# seller_type_Individual                 0.116236
# seller_type_Trustmark Dealer          -0.046814
# transmission_Manual                    0.072274
# owner_Fourth & Above Owner            -0.040040
# owner_Second Owner                    -0.160041
# owner_Test Drive Car                  -0.006716
# owner_Third Owner                      1.000000

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## categorical data

# %%
df_categorical=[ 'fuel','seller_type', 'transmission', 'owner', 'seats', 'company_name', 'no_of_years']
for i in df[df_categorical].columns:
    cat_vc=df[i].value_counts()
    print("Graph for {} : total categories= {}".format(i, len(cat_vc)))
    sns.barplot(x =cat_vc.index ,y = cat_vc)
    plt.xticks(rotation=90)
    plt.show()
# Out:
# Graph for fuel : total categories= 4
# Graph for seller_type : total categories= 3
# Graph for transmission : total categories= 2
# Graph for owner : total categories= 5
# Graph for seats : total categories= 10
# Graph for company_name : total categories= 32
# Graph for no_of_years : total categories= 29
